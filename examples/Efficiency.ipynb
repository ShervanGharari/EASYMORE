# %%
import geopandas as gpd

shp = gpd.read_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA.shp')
shp = shp.to_crs("EPSG:4326")
shp.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_WGS84.shp')

shp_1 = shp.iloc[0:1]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1.shp')
shp_1 = shp.iloc[0:10]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10.shp')
shp_1 = shp.iloc[0:100]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100.shp')
shp_1 = shp.iloc[0:1000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1000.shp')
shp_1 = shp.iloc[0:10000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10000.shp')
shp_1 = shp.iloc[0:100000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100000.shp')

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_WGS84.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:41:49.064517
# Ended   at date and time 2021-04-16 23:41:54.007727
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:41:54.065841
# Ended   at date and time 2021-04-16 23:41:58.913500
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:41:58.968850
# Ended   at date and time 2021-04-16 23:42:03.076105
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:42:31.020087
# Ended   at date and time 2021-04-16 23:42:35.514860
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:42:35.569981
# Ended   at date and time 2021-04-16 23:42:39.237033
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:42:39.288393
# Ended   at date and time 2021-04-16 23:42:42.939496
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:42:48.235098
# Ended   at date and time 2021-04-16 23:42:52.021767
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:42:52.103161
# Ended   at date and time 2021-04-16 23:42:55.773000
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:42:55.824607
# Ended   at date and time 2021-04-16 23:42:59.502383
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:43:05.112437
# Ended   at date and time 2021-04-16 23:43:08.860323
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:43:08.907537
# Ended   at date and time 2021-04-16 23:43:12.562649
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:43:12.609097
# Ended   at date and time 2021-04-16 23:43:16.263825
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:43:21.786558
# Ended   at date and time 2021-04-16 23:43:25.583535
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:43:25.681492
# Ended   at date and time 2021-04-16 23:43:29.311320
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:43:29.364997
# Ended   at date and time 2021-04-16 23:43:33.007579
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:43:38.571726
# Ended   at date and time 2021-04-16 23:43:42.676522
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:43:42.725235
# Ended   at date and time 2021-04-16 23:43:46.734641
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:43:46.783517
# Ended   at date and time 2021-04-16 23:43:50.706648
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:43:58.345132
# Ended   at date and time 2021-04-16 23:44:03.020493
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:44:03.069644
# Ended   at date and time 2021-04-16 23:44:07.462964
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:44:07.511381
# Ended   at date and time 2021-04-16 23:44:11.939299
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:44:18.118385
# Ended   at date and time 2021-04-16 23:44:21.893477
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:44:21.939530
# Ended   at date and time 2021-04-16 23:44:25.632638
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:44:25.678791
# Ended   at date and time 2021-04-16 23:44:29.355339
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:44:34.974938
# Ended   at date and time 2021-04-16 23:44:38.731282
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:44:38.778629
# Ended   at date and time 2021-04-16 23:44:42.425801
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:44:42.473982
# Ended   at date and time 2021-04-16 23:44:46.146593
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-16 23:44:51.705678
# Ended   at date and time 2021-04-16 23:44:55.445746
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-16 23:44:55.491729
# Ended   at date and time 2021-04-16 23:44:59.121478
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-16 23:44:59.167739
# Ended   at date and time 2021-04-16 23:45:02.768758
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_100000'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_100000.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_100000_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_100000_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_100000_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_100000_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:03:55.716667
# Ended   at date and time 2021-04-17 00:03:56.671307
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:03:56.698679
# Ended   at date and time 2021-04-17 00:03:57.577026
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:03:57.602748
# Ended   at date and time 2021-04-17 00:03:58.497173
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:03.107621
# Ended   at date and time 2021-04-17 00:04:04.046297
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:04.067880
# Ended   at date and time 2021-04-17 00:04:04.982673
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:05.005340
# Ended   at date and time 2021-04-17 00:04:05.949597
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:07.629367
# Ended   at date and time 2021-04-17 00:04:08.528077
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:08.547639
# Ended   at date and time 2021-04-17 00:04:09.433071
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:09.458633
# Ended   at date and time 2021-04-17 00:04:10.371096
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:11.857487
# Ended   at date and time 2021-04-17 00:04:12.760429
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:12.784393
# Ended   at date and time 2021-04-17 00:04:13.641608
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:13.665654
# Ended   at date and time 2021-04-17 00:04:14.521937
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:15.995062
# Ended   at date and time 2021-04-17 00:04:16.902818
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:16.925771
# Ended   at date and time 2021-04-17 00:04:17.834285
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:17.855354
# Ended   at date and time 2021-04-17 00:04:18.740616
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:20.198859
# Ended   at date and time 2021-04-17 00:04:21.097078
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:21.119227
# Ended   at date and time 2021-04-17 00:04:22.044410
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:22.064353
# Ended   at date and time 2021-04-17 00:04:22.944812
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:24.421727
# Ended   at date and time 2021-04-17 00:04:25.328515
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:25.349129
# Ended   at date and time 2021-04-17 00:04:26.272831
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:26.294622
# Ended   at date and time 2021-04-17 00:04:27.181038
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:28.649644
# Ended   at date and time 2021-04-17 00:04:29.613430
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:29.635655
# Ended   at date and time 2021-04-17 00:04:30.716269
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:30.745277
# Ended   at date and time 2021-04-17 00:04:31.795932
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:33.595255
# Ended   at date and time 2021-04-17 00:04:34.597946
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:34.620729
# Ended   at date and time 2021-04-17 00:04:35.542968
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:35.563677
# Ended   at date and time 2021-04-17 00:04:36.458202
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:04:37.921900
# Ended   at date and time 2021-04-17 00:04:38.978775
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:04:39.006286
# Ended   at date and time 2021-04-17 00:04:40.063370
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:04:40.089857
# Ended   at date and time 2021-04-17 00:04:41.214023
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_10000'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_10000.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_10000_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_10000_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_10000_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_10000_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:09:53.950435
# Ended   at date and time 2021-04-17 00:09:54.285975
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:09:54.296159
# Ended   at date and time 2021-04-17 00:09:54.633695
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:09:54.643790
# Ended   at date and time 2021-04-17 00:09:54.966268
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:09:56.362930
# Ended   at date and time 2021-04-17 00:09:56.685377
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:09:56.694199
# Ended   at date and time 2021-04-17 00:09:57.015760
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:09:57.024105
# Ended   at date and time 2021-04-17 00:09:57.355567
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:09:57.567840
# Ended   at date and time 2021-04-17 00:09:57.862015
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:09:57.868034
# Ended   at date and time 2021-04-17 00:09:58.134366
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:09:58.141368
# Ended   at date and time 2021-04-17 00:09:58.416163
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:09:58.614267
# Ended   at date and time 2021-04-17 00:09:58.937012
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:09:58.942842
# Ended   at date and time 2021-04-17 00:09:59.220501
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:09:59.227948
# Ended   at date and time 2021-04-17 00:09:59.564381
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:09:59.791804
# Ended   at date and time 2021-04-17 00:10:00.075557
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:00.081576
# Ended   at date and time 2021-04-17 00:10:00.389108
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:00.396550
# Ended   at date and time 2021-04-17 00:10:00.720977
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:10:00.905635
# Ended   at date and time 2021-04-17 00:10:01.229374
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:01.239507
# Ended   at date and time 2021-04-17 00:10:01.519194
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:01.527635
# Ended   at date and time 2021-04-17 00:10:01.800182
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:10:01.997402
# Ended   at date and time 2021-04-17 00:10:02.332507
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:02.340099
# Ended   at date and time 2021-04-17 00:10:02.651729
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:02.659662
# Ended   at date and time 2021-04-17 00:10:02.978050
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:10:03.158320
# Ended   at date and time 2021-04-17 00:10:03.497549
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:03.506948
# Ended   at date and time 2021-04-17 00:10:03.819961
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:03.828343
# Ended   at date and time 2021-04-17 00:10:04.157976
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:10:04.371243
# Ended   at date and time 2021-04-17 00:10:04.689899
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:04.696216
# Ended   at date and time 2021-04-17 00:10:04.973484
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:04.981572
# Ended   at date and time 2021-04-17 00:10:05.313424
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:10:05.533561
# Ended   at date and time 2021-04-17 00:10:05.841170
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:10:05.847627
# Ended   at date and time 2021-04-17 00:10:06.113220
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:10:06.119485
# Ended   at date and time 2021-04-17 00:10:06.449249
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_1000'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_1000.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_1000_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_1000_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_1000_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_1000_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:50.771312
# Ended   at date and time 2021-04-17 00:13:51.012176
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:51.022068
# Ended   at date and time 2021-04-17 00:13:51.260848
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:51.268938
# Ended   at date and time 2021-04-17 00:13:51.530964
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:52.672792
# Ended   at date and time 2021-04-17 00:13:52.882158
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:52.886497
# Ended   at date and time 2021-04-17 00:13:53.092598
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:53.097433
# Ended   at date and time 2021-04-17 00:13:53.324058
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:53.397683
# Ended   at date and time 2021-04-17 00:13:53.642957
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:53.647491
# Ended   at date and time 2021-04-17 00:13:53.857937
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:53.862544
# Ended   at date and time 2021-04-17 00:13:54.071782
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:54.133539
# Ended   at date and time 2021-04-17 00:13:54.341677
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:54.346488
# Ended   at date and time 2021-04-17 00:13:54.553606
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:54.558808
# Ended   at date and time 2021-04-17 00:13:54.778441
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:54.843627
# Ended   at date and time 2021-04-17 00:13:55.048244
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:55.053302
# Ended   at date and time 2021-04-17 00:13:55.258460
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:55.263314
# Ended   at date and time 2021-04-17 00:13:55.468824
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:55.528644
# Ended   at date and time 2021-04-17 00:13:55.750137
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:55.754748
# Ended   at date and time 2021-04-17 00:13:55.968041
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:55.974250
# Ended   at date and time 2021-04-17 00:13:56.193588
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:56.253154
# Ended   at date and time 2021-04-17 00:13:56.460101
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:56.464748
# Ended   at date and time 2021-04-17 00:13:56.668558
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:56.673857
# Ended   at date and time 2021-04-17 00:13:56.885887
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:56.945919
# Ended   at date and time 2021-04-17 00:13:57.156053
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:57.160685
# Ended   at date and time 2021-04-17 00:13:57.386105
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:57.391729
# Ended   at date and time 2021-04-17 00:13:57.626093
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:57.692272
# Ended   at date and time 2021-04-17 00:13:57.914775
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:57.920515
# Ended   at date and time 2021-04-17 00:13:58.129477
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:58.135513
# Ended   at date and time 2021-04-17 00:13:58.369950
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:13:58.434551
# Ended   at date and time 2021-04-17 00:13:58.652760
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:13:58.657260
# Ended   at date and time 2021-04-17 00:13:58.863697
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1000_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:13:58.868899
# Ended   at date and time 2021-04-17 00:13:59.074726
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_100'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_100.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_100_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_100_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_100_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_100_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:38.363207
# Ended   at date and time 2021-04-17 00:17:38.606709
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:38.614006
# Ended   at date and time 2021-04-17 00:17:38.878687
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:38.887070
# Ended   at date and time 2021-04-17 00:17:39.139164
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:40.317557
# Ended   at date and time 2021-04-17 00:17:40.579614
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:40.585948
# Ended   at date and time 2021-04-17 00:17:40.816309
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:40.820838
# Ended   at date and time 2021-04-17 00:17:41.077915
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:41.141662
# Ended   at date and time 2021-04-17 00:17:41.390868
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:41.395993
# Ended   at date and time 2021-04-17 00:17:41.662123
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:41.668916
# Ended   at date and time 2021-04-17 00:17:41.959258
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:42.017054
# Ended   at date and time 2021-04-17 00:17:42.250529
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:42.254996
# Ended   at date and time 2021-04-17 00:17:42.506831
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:42.513558
# Ended   at date and time 2021-04-17 00:17:42.785002
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:42.842116
# Ended   at date and time 2021-04-17 00:17:43.050808
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:43.055673
# Ended   at date and time 2021-04-17 00:17:43.309609
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:43.315304
# Ended   at date and time 2021-04-17 00:17:43.582782
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:43.648179
# Ended   at date and time 2021-04-17 00:17:43.909449
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:43.915313
# Ended   at date and time 2021-04-17 00:17:44.141435
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:44.146643
# Ended   at date and time 2021-04-17 00:17:44.350189
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:44.413613
# Ended   at date and time 2021-04-17 00:17:44.697237
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:44.702784
# Ended   at date and time 2021-04-17 00:17:44.904902
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:44.910545
# Ended   at date and time 2021-04-17 00:17:45.164401
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:45.222046
# Ended   at date and time 2021-04-17 00:17:45.483729
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:45.500071
# Ended   at date and time 2021-04-17 00:17:45.754896
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:45.761222
# Ended   at date and time 2021-04-17 00:17:46.063704
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:46.139641
# Ended   at date and time 2021-04-17 00:17:46.466155
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:46.473945
# Ended   at date and time 2021-04-17 00:17:46.811764
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:46.819148
# Ended   at date and time 2021-04-17 00:17:47.095650
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:17:47.160205
# Ended   at date and time 2021-04-17 00:17:47.534942
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:17:47.547580
# Ended   at date and time 2021-04-17 00:17:47.912047
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_100_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:17:47.918193
# Ended   at date and time 2021-04-17 00:17:48.209202
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_10'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_10.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_10_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_10_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_10_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_10_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:21.497210
# Ended   at date and time 2021-04-17 00:21:21.728978
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:21.736708
# Ended   at date and time 2021-04-17 00:21:21.976569
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:21.983815
# Ended   at date and time 2021-04-17 00:21:22.215309
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:23.351675
# Ended   at date and time 2021-04-17 00:21:23.563805
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:23.571235
# Ended   at date and time 2021-04-17 00:21:23.776550
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:23.781561
# Ended   at date and time 2021-04-17 00:21:23.986244
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:24.039899
# Ended   at date and time 2021-04-17 00:21:24.254709
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:24.259658
# Ended   at date and time 2021-04-17 00:21:24.462440
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:24.467983
# Ended   at date and time 2021-04-17 00:21:24.681094
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:24.733025
# Ended   at date and time 2021-04-17 00:21:24.947661
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:24.952855
# Ended   at date and time 2021-04-17 00:21:25.161599
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:25.166442
# Ended   at date and time 2021-04-17 00:21:25.375409
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:25.428175
# Ended   at date and time 2021-04-17 00:21:25.639119
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:25.643324
# Ended   at date and time 2021-04-17 00:21:25.869161
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:25.874924
# Ended   at date and time 2021-04-17 00:21:26.102010
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:26.153453
# Ended   at date and time 2021-04-17 00:21:26.370408
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:26.375382
# Ended   at date and time 2021-04-17 00:21:26.586058
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:26.592537
# Ended   at date and time 2021-04-17 00:21:26.802829
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:26.855563
# Ended   at date and time 2021-04-17 00:21:27.068414
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:27.075267
# Ended   at date and time 2021-04-17 00:21:27.285020
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:27.290339
# Ended   at date and time 2021-04-17 00:21:27.497095
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:27.551353
# Ended   at date and time 2021-04-17 00:21:27.761200
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:27.765968
# Ended   at date and time 2021-04-17 00:21:27.967463
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:27.973109
# Ended   at date and time 2021-04-17 00:21:28.189703
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:28.242040
# Ended   at date and time 2021-04-17 00:21:28.447571
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:28.452264
# Ended   at date and time 2021-04-17 00:21:28.660723
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:28.665599
# Ended   at date and time 2021-04-17 00:21:28.870643
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:21:28.926041
# Ended   at date and time 2021-04-17 00:21:29.139848
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:21:29.144154
# Ended   at date and time 2021-04-17 00:21:29.350134
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_10_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:21:29.355017
# Ended   at date and time 2021-04-17 00:21:29.562215
# ------

# %%
# loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying candex objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ERA5_Merit_NA_1'              
# temporary path that the candex generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'
# name of target shapefile that the source netcdf files should be remapped to
esmr.target_shp               = '/Users/shg096/Desktop/catEndoMERITpfaf_NA_1.shp'
# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = '../data/Source_nc_ERA5/ERA5_NA_*.nc'
# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ['airtemp','pptrate']
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'longitude'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'latitude'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = '../output/'

# execute candex
esmr.nc_remapper()
esmr.remap_csv                = '../temporary/ERA5_Merit_NA_1_remapping.csv'
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE is given multiple varibales to be remapped but only on format and fill valueEASYMORE repeat the format and fill value for all the variables in output files
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in equal area projection
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# point shapefile for centroid of the shapes is saves here:
# ../temporary/ERA5_Merit_NA_1_centroid.shp
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ERA5_Merit_NA_1_target_shapefile.shp
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# EASYMORE detects case 1 - regular lat/lon
# EASYMORE is creating the shapefile from the netCDF file and saving it here:
# ../temporary/ERA5_Merit_NA_1_source_shapefile.shp
# -170.125 4.875 -49.875 75.125
# EASYMORE decides the netCDF file has longtitude values of -180 to 180; creating the extended
# /Users/shg096/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/easymore/easymore.py:145: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shp_int.to_file(self.temp_dir+self.case_name+'_intersected_shapefile.shp') # save the intersected files
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:00.844691
# Ended   at date and time 2021-04-17 00:25:01.075780
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:01.083172
# Ended   at date and time 2021-04-17 00:25:01.304484
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:01.312727
# Ended   at date and time 2021-04-17 00:25:01.528706
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:02.684965
# Ended   at date and time 2021-04-17 00:25:02.991309
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:02.996215
# Ended   at date and time 2021-04-17 00:25:03.229595
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:03.234137
# Ended   at date and time 2021-04-17 00:25:03.433487
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:03.485875
# Ended   at date and time 2021-04-17 00:25:03.689903
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:03.694073
# Ended   at date and time 2021-04-17 00:25:03.898016
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:03.902858
# Ended   at date and time 2021-04-17 00:25:04.146101
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:04.206641
# Ended   at date and time 2021-04-17 00:25:04.413858
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:04.419108
# Ended   at date and time 2021-04-17 00:25:04.632458
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:04.636766
# Ended   at date and time 2021-04-17 00:25:04.845525
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:04.908451
# Ended   at date and time 2021-04-17 00:25:05.120179
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:05.125125
# Ended   at date and time 2021-04-17 00:25:05.323292
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:05.328532
# Ended   at date and time 2021-04-17 00:25:05.532880
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:05.589231
# Ended   at date and time 2021-04-17 00:25:05.793899
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:05.798669
# Ended   at date and time 2021-04-17 00:25:06.001740
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:06.007311
# Ended   at date and time 2021-04-17 00:25:06.208999
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:06.259613
# Ended   at date and time 2021-04-17 00:25:06.459776
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:06.464937
# Ended   at date and time 2021-04-17 00:25:06.693600
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:06.700571
# Ended   at date and time 2021-04-17 00:25:06.960595
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:07.010303
# Ended   at date and time 2021-04-17 00:25:07.214860
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:07.220150
# Ended   at date and time 2021-04-17 00:25:07.415443
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:07.421349
# Ended   at date and time 2021-04-17 00:25:07.623392
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:07.673935
# Ended   at date and time 2021-04-17 00:25:07.889678
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:07.895760
# Ended   at date and time 2021-04-17 00:25:08.184728
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:08.191722
# Ended   at date and time 2021-04-17 00:25:08.417884
# ------
# remap file is provided; EASYMORE will use this file and skip calculation of remapping
# EASYMORE will remap variable  airtemp  from source file to variable  airtemp  in remapped NeCDF file
# EASYMORE will remap variable  pptrate  from source file to variable  pptrate  in remapped NeCDF file
# EASYMORE case exists in the remap file
# EASYMORE detects that the varibales from the netCDF files are identicalin dimensions of the varibales and latitude and longitude
# EASYMORE detects that all the varibales have dimensions of:
# ['time', 'latitude', 'longitude']
# EASYMORE detects that the longitude varibales has dimensions of:
# ['longitude']
# EASYMORE detects that the latitude varibales has dimensions of:
# ['latitude']
# ------REMAPPING------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790101.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-01-00-00-00.nc
# Started at date and time 2021-04-17 00:25:08.468869
# Ended   at date and time 2021-04-17 00:25:08.676583
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790102.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-02-00-00-00.nc
# Started at date and time 2021-04-17 00:25:08.681745
# Ended   at date and time 2021-04-17 00:25:08.876299
# ------
# Remapping ../data/Source_nc_ERA5/ERA5_NA_19790103.nc to ../output/ERA5_Merit_NA_1_remapped_1979-01-03-00-00-00.nc
# Started at date and time 2021-04-17 00:25:08.881830
# Ended   at date and time 2021-04-17 00:25:09.088044
# ------

# %%
file = open('/Users/shg096/Desktop/candex_newgen/output/462315.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT462315              =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/100000.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT100000              =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/10000.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT10000               =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/1000.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT1000                =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/100.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT100                 =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/10.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT10                  =  np.array(df ['delta'].dt.total_seconds())

###
file = open('/Users/shg096/Desktop/candex_newgen/output/1.txt',"r") # open the master file
list_variables = file.readlines(); file.close() # read lines and close the file

df = pd.DataFrame()
df = pd.DataFrame(columns=['start', 'end'])
    
m = 0
for i in np.arange (len(list_variables)):
    if 'Started at date and time ' in list_variables[i]:
        start = list_variables[i][25:]
    if 'Ended   at date and time ' in list_variables[i]:
        end = list_variables[i][25:]
        df.loc[m] = list ([start, end])
        m = m + 1

df ['start_datetime'] =  pd.to_datetime(df['start'], format='%Y-%m-%d %H:%M:%S.%f')
df ['end_datetime']   =  pd.to_datetime(df['end'],   format='%Y-%m-%d %H:%M:%S.%f')
df ['delta']          =  df ['end_datetime'] - df ['start_datetime']
DT1                   =  np.array(df ['delta'].dt.total_seconds())

Q95 = np.array([np.quantile(DT1, 0.95),np.quantile(DT10, 0.95),np.quantile(DT100, 0.95),\
                np.quantile(DT1000, 0.95),np.quantile(DT10000, 0.95),np.quantile(DT100000,0.95),\
                np.quantile(DT462315, 0.95)])

Q05 = np.array([np.quantile(DT1, 0.05),np.quantile(DT10, 0.05),np.quantile(DT100, 0.05),\
                np.quantile(DT1000, 0.05),np.quantile(DT10000, 0.05),np.quantile(DT100000,0.05),\
                np.quantile(DT462315, 0.05)])

Qmean = np.array([np.mean(DT1),np.mean(DT10),np.mean(DT100),\
                np.mean(DT1000),np.mean(DT10000),np.mean(DT100000),\
                np.mean(DT462315)])

X = np.array([1,10,100,1000,10000,100000,462315])

scale = np.array([Qmean[0],Qmean[0]*10,Qmean[0]*100,Qmean[0]*1000,Qmean[0]*10000,Qmean[0]*100000,Qmean[0]*462315])



import matplotlib.pyplot as plt
import matplotlib
font = {'family' : 'Times New Roman',
         'weight' : 'bold',
         'size'   : 24}
matplotlib.rc('font', **font)


# #
# fig1, ax1 = plt.subplots(1,1,figsize=(15,7))
# ax1.set_title('Basic Plot')
# ax1.set_xlabel('Number of sink shapes [-]')
# #ax1.plot(X,Q95,'b')
# #ax1.plot(X,Q05,'b')
# ax1.plot(X,Qmean)
# #ax1.plot(X,scale)
# #ax1.set_xscale('log')
# ax1.grid()
# plt.savefig('../fig/Example7_A.png', bbox_inches='tight')


#
dfT = pd.DataFrame()
f, axes = plt.subplots(1,1,figsize=(15,7))
dfT['Time [s]'] = Qmean
dfT['N'] = np.array([1,10,100,1000,10000,100000,462315])
dfT = dfT.set_index('N')
print(dfT)
dfT.plot.bar(ax = axes)
plt.grid()
plt.ylabel('Processing time [s]')
plt.xlabel('Number of sink shapes [-]')
plt.savefig('../fig/Example7_A.png', bbox_inches='tight')




# import matplotlib.pyplot as plt
# fig1, ax1 = plt.subplots()
# ax1.set_title('Basic Plot')
# ax1.boxplot(DT1,positions=[1])
# ax1.boxplot(DT10,positions=[2])
# ax1.boxplot(DT100,positions=[3])
# ax1.boxplot(DT1000,positions=[4])
# ax1.boxplot(DT10000,positions=[5])
# ax1.boxplot(DT100000,positions=[6])
# ax1.boxplot(DT462315,positions=[6.4])
# Out:
#         Time [s]
# N
# 1       0.234602
# 10      0.242471
# 100     0.240470
# 1000    0.254993
# 10000   0.356706
# 100000  0.981923
# 462315  4.256780

# %%
import datetime
import numpy as np

## 462315
diff_462315 = np.zeros([3,])

Started = datetime.datetime.strptime('2021-03-03 12:27:52.852567', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:27:57.103611', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_462315[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:27:57.125069', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:28:00.834283', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_462315[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:28:00.860123', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:28:04.553557', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_462315[2] = diff.total_seconds()
        
## 100,000
diff_100000 = np.zeros([3,])

Started = datetime.datetime.strptime('2021-03-03 12:42:39.309155', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:42:40.183651', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100000[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:42:40.199492', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:42:41.116093', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100000[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:42:41.130033', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:42:42.027740', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100000[2] = diff.total_seconds()

## 10,000
diff_10000 = np.zeros([3,])

Started = datetime.datetime.strptime('2021-03-03 12:46:44.351986', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:46:44.628791', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10000[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:46:44.635944', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:46:44.923614', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10000[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:46:44.929651', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:46:45.205588', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10000[2] = diff.total_seconds()
        
## 1,000
diff_1000 = np.zeros([3,])

Started = datetime.datetime.strptime('2021-03-03 12:49:52.539574', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:49:52.763419', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1000[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:49:52.770218', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:49:53.013365', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1000[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:49:53.019049', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:49:53.232545', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1000[2] = diff.total_seconds()

        
## 100
diff_100 = np.zeros([3,])
Started = datetime.datetime.strptime('2021-03-03 12:53:11.636817', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:53:11.856614', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:53:11.863014', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:53:12.113893', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:53:12.121214', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:53:12.369592', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_100[2] = diff.total_seconds()
        
## 10
diff_10 = np.zeros([3,])
Started = datetime.datetime.strptime('2021-03-03 12:56:29.987543', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:56:30.202544', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:56:30.208051', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:56:30.470768', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:56:30.476007', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:56:30.706316', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_10[2] = diff.total_seconds()


## 1
diff_1 = np.zeros([3,])
Started = datetime.datetime.strptime('2021-03-03 12:59:46.932064', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:59:47.184573', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1[0] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:59:47.191582', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:59:47.402587', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1[1] = diff.total_seconds()

Started = datetime.datetime.strptime('2021-03-03 12:59:47.408495', '%Y-%m-%d %H:%M:%S.%f')
Ended   = datetime.datetime.strptime('2021-03-03 12:59:47.638101', '%Y-%m-%d %H:%M:%S.%f')
diff    = Ended - Started
diff_1[2] = diff.total_seconds()

# %%
import pandas as pd

# plotting
df   = pd.DataFrame()
df = df.append({'462315': np.mean(diff_462315), '100000': np.mean(diff_100000),\
                '10000':  np.mean(diff_10000),  '1000': np.mean(diff_1000),\
                '100':    np.mean(diff_100),    '10': np.mean(diff_10),\
                '1':      np.mean(diff_1)}, ignore_index=True)

print(df)
# Out:
#          1        10       100      1000     10000    100000    462315
# 0  0.23104  0.236009  0.239685  0.226829  0.280137  0.896268  3.884564

# %%
import matplotlib.pyplot as plt
import matplotlib
font = {'family' : 'Times New Roman',
         'weight' : 'bold',
         'size'   : 24}
matplotlib.rc('font', **font)

f, axes = plt.subplots(1,1,figsize=(15,7))
dfT = df.T
dfT.plot.bar(ax = axes)
plt.grid()
plt.ylabel('Process time [s]')
plt.xlabel('Number of sink shapes [-]')
plt.savefig('../fig/Example7_A.png', bbox_inches='tight')


f, axes = plt.subplots(1,1,figsize=(15,7))
Y = np.array(df)
Y = Y.flatten()
print(Y)
X = np.array([1,10,100,1000,10000,100000,462315])
X = X.flatten()
plt.plot(X,Y)
plt.grid()
plt.ylabel('Process time [s]')
plt.xlabel('Number of sink shapes [-]')
plt.xscale("log")
plt.savefig('../fig/Example7_B.png', bbox_inches='tight')

f, axes = plt.subplots(1,1,figsize=(15,7))
Y = np.array(df)
Y = Y.flatten()
print(Y)
X = np.array([1,10,100,1000,10000,100000,462315])
X = X.flatten()
plt.plot(X,Y)
plt.grid()
plt.ylabel('Process time [s]')
plt.xlabel('Number of sink shapes [-]')
plt.savefig('../fig/Example7_C.png', bbox_inches='tight')
# Out:
# [0.23104    0.236009   0.23968467 0.22682933 0.28013733 0.896268
#  3.884564  ]
# [0.23104    0.236009   0.23968467 0.22682933 0.28013733 0.896268
#  3.884564  ]

# %%
A = len(shp)
print(A)

shp_1 = shp.iloc[0:1]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1.shp')

shp_1 = shp.iloc[0:10]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10.shp')

shp_1 = shp.iloc[0:100]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100.shp')

shp_1 = shp.iloc[0:1000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1000.shp')

shp_1 = shp.iloc[0:10000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10000.shp')

shp_1 = shp.iloc[0:100000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100000.shp')
# Out:
# 462315

# %%
import geopandas as gpd

shp = gpd.read_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA.shp')

shp = shp.to_crs("EPSG:4326")

shp.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_WGS84.shp')

# %%
import geopandas as gpd

shp = gpd.read_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA.shp')

shp = shp.to_crs("EPSG:4326")

shp.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_WGS84.shp')

shp_1 = shp.iloc[0:1]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1.shp')

shp_1 = shp.iloc[0:10]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10.shp')

shp_1 = shp.iloc[0:100]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100.shp')

shp_1 = shp.iloc[0:1000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_1000.shp')

shp_1 = shp.iloc[0:10000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_10000.shp')

shp_1 = shp.iloc[0:100000]
shp_1.to_file('/Users/shg096/Desktop/catEndoMERITpfaf_NA_100000.shp')
# Out:
# 462315
